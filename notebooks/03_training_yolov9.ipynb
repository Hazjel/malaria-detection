# %% [markdown]
# # 03 - Training YOLOv9 (Baseline 2)
#
# Notebook ini melatih YOLOv9 sebagai baseline kedua.
# YOLOv9 menggunakan arsitektur GELAN (Generalized Efficient Layer Aggregation Network)
# dan PGI (Programmable Gradient Information) yang berbeda dari YOLOv8.
# Urutan: setup -> load config -> training -> evaluasi -> simpan hasil.

# %% [markdown]
# ## Setup Environment

# %%
import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    import os
    PROJECT_ROOT = '/content/drive/MyDrive/malaria-detection'
    os.chdir(PROJECT_ROOT)
else:
    import os
    PROJECT_ROOT = os.path.abspath('..')
    os.chdir(PROJECT_ROOT)

print('working directory:', os.getcwd())
# Out:
# working directory: d:\malaria-detection

# %%
# !pip install -q ultralytics
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import time
import cv2
from pathlib import Path

import torch
from ultralytics import YOLO

# %%
# cek gpu
print('torch version :', torch.__version__)
print('cuda available:', torch.cuda.is_available())

if torch.cuda.is_available():
    print('gpu           :', torch.cuda.get_device_name(0))
    DEVICE = 0
else:
    print('gpu tidak ditemukan, training pakai cpu')
    DEVICE = 'cpu'
# Out:
# torch version : 2.5.1+cu121
# cuda available: True
# gpu           : NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# load summary dari notebook 01
summary_path = os.path.join(PROJECT_ROOT, 'notebook01_summary.json')

if not os.path.exists(summary_path):
    raise FileNotFoundError('notebook01_summary.json tidak ditemukan, pastikan notebook 01 sudah dijalankan')

with open(summary_path) as f:
    summary = json.load(f)

print('status notebook 01:', summary['status'])
print('train            :', summary['total_train'], 'gambar')
print('val              :', summary['total_val'], 'gambar')
print('test             :', summary['total_test'], 'gambar')

YAML_PATH = summary['yaml_path']
# Out:
# status notebook 01: done
# train            : 21676 gambar
# val              : 5606 gambar
# test             : 2803 gambar

# %% [markdown]
# ## Training YOLOv9

# %%
SAVE_DIR = os.path.join(PROJECT_ROOT, 'runs', 'yolov9')
os.makedirs(SAVE_DIR, exist_ok=True)

print('hasil training akan disimpan di:', SAVE_DIR)
# Out:
# hasil training akan disimpan di: d:\malaria-detection\runs\yolov9

# %%
# yolov9c dipilih karena ukurannya seimbang
# tersedia: yolov9t, yolov9s, yolov9m, yolov9c, yolov9e
# t = tiny, s = small, c = compact, e = extra large
# yolov9s setara ukurannya dengan yolov8s dalam hal keseimbangan speed vs accuracy
model = YOLO('yolov9s.pt')

total_params = sum(p.numel() for p in model.model.parameters())
print(f'model yolov9s loaded')
print(f'total parameter: {total_params:,}')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov9s.pt to 'yolov9s.pt': 100% ━━━━━━━━━━━━ 14.7MB 5.9MB/s 2.5s 2.5s<0.0ss
# model yolov9s loaded
# total parameter: 7,318,368

# %%
# training dengan hyperparameter yang sama persis dengan notebook 02 dan 04
results = model.train(
    data        = YAML_PATH,
    epochs      = 100,
    imgsz       = 640,
    batch       = 16,
    optimizer   = 'AdamW',
    lr0         = 0.001,
    patience    = 20,
    device      = DEVICE,
    project     = SAVE_DIR,
    name        = 'train',
    save        = True,
    save_period = 10,
    exist_ok    = True,
    verbose     = True,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56  Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=d:\malaria-detection\malaria.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov9s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=d:\malaria-detection\runs\yolov9, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\malaria-detection\runs\yolov9\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     31104  ultralytics.nn.modules.block.ELAN1           [64, 64, 64, 32]
#   3                  -1  1     73984  ultralytics.nn.modules.block.AConv           [64, 128]
#   4                  -1  1    258432  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 128, 128, 64, 3]
#   5                  -1  1    221568  ultralytics.nn.modules.block.AConv           [128, 192]
#   6                  -1  1    579648  ultralytics.nn.modules.block.RepNCSPELAN4    [192, 192, 192, 96, 3]
#   7                  -1  1    442880  ultralytics.nn.modules.block.AConv           [192, 256]
#   8                  -1  1   1028864  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 256, 256, 128, 3]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPELAN         [256, 256, 128]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    628800  ultralytics.nn.modules.block.RepNCSPELAN4    [448, 192, 192, 96, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    283008  ultralytics.nn.modules.block.RepNCSPELAN4    [320, 128, 128, 64, 3]
#  16                  -1  1    110784  ultralytics.nn.modules.block.AConv           [128, 96]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    598080  ultralytics.nn.modules.block.RepNCSPELAN4    [288, 192, 192, 96, 3]
#  19                  -1  1    221440  ultralytics.nn.modules.block.AConv           [192, 128]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1061632  ultralytics.nn.modules.block.RepNCSPELAN4    [384, 256, 256, 128, 3]
#  22        [15, 18, 21]  1   1563862  ultralytics.nn.modules.head.Detect           [2, 16, None, [128, 192, 256]]
# YOLOv9s summary: 544 layers, 7,288,182 parameters, 7,288,166 gradients, 27.4 GFLOPs
#
# Transferred 1333/1339 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 123.739.7 MB/s, size: 54.5 KB)
# train: Scanning D:\malaria-detection\datasets\processed\labels\train.cache... 21676 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21676/21676  0.0s
# train: D:\malaria-detection\datasets\processed\images\train\mpidb_0237.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.20.1 ms, read: 72.417.4 MB/s, size: 53.1 KB)
# val: Scanning D:\malaria-detection\datasets\processed\labels\val.cache... 5606 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5606/5606  0.0s
# val: D:\malaria-detection\datasets\processed\images\val\mpidb_0236.jpg: 1 duplicate labels removed
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 221 weight(decay=0.0), 228 weight(decay=0.0005), 227 bias(decay=0.0)
# Plotting labels to D:\malaria-detection\runs\yolov9\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\malaria-detection\runs\yolov9\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.79G     0.1955     0.6807     0.9597         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.6it/s 8:44<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.9s0.3ss
#                    all       5606       6279      0.838      0.861      0.898      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.75G     0.1509     0.5745      0.925         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:48<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.3s0.3ss
#                    all       5606       6279      0.882      0.854      0.922      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.63G     0.1265     0.5436     0.9135         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.3s0.3ss
#                    all       5606       6279      0.941      0.845      0.924      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.64G     0.1101      0.518     0.9051         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.8s0.3ss
#                    all       5606       6279      0.954      0.849      0.937      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.76G    0.09732     0.5046     0.9008         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.1s0.3ss
#                    all       5606       6279      0.905      0.893      0.945      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.92G    0.09399     0.5042     0.9002         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:30<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.1s0.3ss
#                    all       5606       6279      0.921      0.892      0.941      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.63G    0.08572     0.4884     0.8977         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.1it/s 7:24<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.4s0.3ss
#                    all       5606       6279       0.92      0.917       0.95       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.64G    0.08201     0.4831     0.8958         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.2s0.3ss
#                    all       5606       6279      0.928        0.9      0.947      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.78G    0.08209     0.4819     0.8965         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 49.8s0.3ss
#                    all       5606       6279       0.93      0.905      0.948      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.64G    0.07575     0.4727     0.8961         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 49.7s0.3ss
#                    all       5606       6279      0.921      0.917      0.949       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.77G    0.07722     0.4683      0.896         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:24<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.2s0.3ss
#                    all       5606       6279       0.93      0.918      0.953      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.64G     0.0743     0.4641     0.8933         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:24<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.6it/s 49.5s0.3ss
#                    all       5606       6279      0.925       0.92      0.955      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.76G    0.07607     0.4596     0.8949         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.6it/s 49.3s0.3ss
#                    all       5606       6279      0.924      0.926      0.953      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.74G    0.07506     0.4571     0.8938         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:24<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 49.6s0.3ss
#                    all       5606       6279      0.928      0.927      0.957      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.73G    0.06704     0.4521     0.8922         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:25<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.6it/s 49.5s0.3ss
#                    all       5606       6279      0.924      0.924      0.955      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.72G    0.06939     0.4466     0.8927         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 49.8s0.3ss
#                    all       5606       6279      0.933      0.927      0.958       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.75G    0.06476     0.4397     0.8914         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.6it/s 49.3s0.3ss
#                    all       5606       6279      0.931      0.931      0.958      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.66G    0.06432      0.441     0.8907         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:26<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.6it/s 49.1s0.3ss
#                    all       5606       6279      0.935      0.913      0.952      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.76G    0.06415     0.4426     0.8907         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.3s0.3ss
#                    all       5606       6279      0.935      0.928      0.959      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.77G    0.05993     0.4408     0.8909         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.2s0.3ss
#                    all       5606       6279      0.938      0.925      0.959      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.65G        inf     0.4384     0.8908         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:30<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.2s0.3ss
#                    all       5606       6279       0.94      0.932       0.96      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.63G     0.0631     0.4339      0.891         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.6s0.3ss
#                    all       5606       6279      0.931      0.932       0.96      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.64G    0.06042     0.4347     0.8898         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.6s0.3ss
#                    all       5606       6279       0.94      0.926       0.96      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.64G        inf     0.4353     0.8892         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.4s0.3ss
#                    all       5606       6279      0.934      0.933      0.961      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.73G     0.0627      0.435     0.8902         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.2s0.3ss
#                    all       5606       6279      0.933      0.934      0.961      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.74G    0.05631     0.4221     0.8896         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.2s0.3ss
#                    all       5606       6279       0.94      0.932      0.962      0.924
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.69G        inf     0.4235     0.8886         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.3s0.3ss
#                    all       5606       6279      0.941      0.931      0.961      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.66G    0.05858     0.4239     0.8893         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:37<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.2it/s 1:200.3sss
#                    all       5606       6279      0.939      0.935      0.962      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.63G    0.05841     0.4276     0.8889         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:51<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 53.4s0.3ss
#                    all       5606       6279      0.937      0.937      0.962      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.63G    0.05611     0.4236     0.8894         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.6s0.3ss
#                    all       5606       6279      0.936      0.936      0.962      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.75G    0.05662     0.4197     0.8898         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.5s0.3ss
#                    all       5606       6279      0.939      0.935      0.962      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.77G    0.05277      0.417     0.8883         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.6s0.3ss
#                    all       5606       6279      0.935      0.939      0.963      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.68G    0.05255     0.4167     0.8885         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:44<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.4s0.3ss
#                    all       5606       6279      0.936      0.938      0.963      0.927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.64G    0.05073     0.4121     0.8871         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.8s0.3ss
#                    all       5606       6279      0.939      0.939      0.963      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.73G        inf     0.4135     0.8901         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.6s0.3ss
#                    all       5606       6279      0.939      0.938      0.963      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.79G        inf     0.4134     0.8892         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:40<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.5s0.3ss
#                    all       5606       6279      0.936      0.939      0.963      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.63G    0.05086       0.41     0.8889         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.5s0.3ss
#                    all       5606       6279      0.936      0.936      0.963      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.65G        inf     0.4127     0.8873         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.0s0.3ss
#                    all       5606       6279      0.939      0.936      0.963      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.77G    0.05843     0.4156     0.8872         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.5s0.3ss
#                    all       5606       6279       0.94      0.938      0.964      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.63G    0.05179     0.4133     0.8866         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.6it/s 8:49<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.5s0.3ss
#                    all       5606       6279       0.94      0.938      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.74G    0.05049     0.4032     0.8859         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.8it/s 8:01<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.2s0.3ss
#                    all       5606       6279      0.944      0.936      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.64G    0.04945     0.4022     0.8882         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.8it/s 7:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.3s0.3ss
#                    all       5606       6279       0.94      0.939      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.65G    0.04938     0.4017     0.8867         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.3s0.3ss
#                    all       5606       6279      0.938       0.94      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.77G    0.05091     0.4056     0.8867         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:39<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.6s0.3ss
#                    all       5606       6279       0.94       0.94      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.74G    0.05087     0.4024     0.8856         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.3s0.3ss
#                    all       5606       6279       0.94       0.94      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.63G    0.05045     0.4028     0.8861         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.6s0.3ss
#                    all       5606       6279      0.938      0.941      0.964      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      4.75G        inf     0.3993     0.8853         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.3s0.3ss
#                    all       5606       6279      0.938      0.941      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.64G        inf     0.3962     0.8876         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:39<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.7s0.3ss
#                    all       5606       6279      0.941      0.938      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.63G    0.04383     0.3885     0.8864         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.1s0.3ss
#                    all       5606       6279      0.942      0.938      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.64G        inf     0.3867     0.8862         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.2s0.3ss
#                    all       5606       6279      0.941      0.938      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      4.64G        inf      0.391     0.8866         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.5s0.3ss
#                    all       5606       6279      0.941      0.938      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.78G     0.0457     0.3926      0.889         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.8s0.3ss
#                    all       5606       6279      0.941       0.94      0.964       0.93
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.63G        inf     0.3924     0.8869         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.5it/s 50.5s0.3ss
#                    all       5606       6279      0.938      0.943      0.965      0.929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.63G     0.0446     0.3851     0.8872         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:31<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.2s0.3ss
#                    all       5606       6279      0.938      0.943       0.96      0.926
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.77G        inf      0.388     0.8849         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 53.4s0.3ss
#                    all       5606       6279       0.94      0.941      0.956      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.74G     0.0432     0.3853     0.8872         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.9s0.3ss
#                    all       5606       6279      0.944      0.938      0.955       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.63G        inf      0.385     0.8859         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.3it/s 54.1s0.3ss
#                    all       5606       6279      0.943      0.938       0.95      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.64G    0.04173     0.3826     0.8861         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.0it/s 57.9s0.3ss
#                    all       5606       6279      0.945      0.936      0.943      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.64G    0.04231     0.3787     0.8858         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.0it/s 59.5s0.4ss
#                    all       5606       6279      0.967      0.902      0.927      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.75G    0.04207      0.381     0.8868         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.8it/s 1:020.4sss
#                    all       5606       6279      0.974      0.886       0.91      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      4.63G    0.04075     0.3791     0.8865         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.7it/s 1:040.4sss
#                    all       5606       6279      0.975       0.88      0.909       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      4.63G    0.04313     0.3805     0.8852         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.5it/s 9:03<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 1.9it/s 1:340.5sss
#                    all       5606       6279      0.976      0.876      0.907      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.76G        inf     0.3775     0.8877         12        640: 100% ━━━━━━━━━━━━ 1355/1355 1.9it/s 11:40<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 1.9it/s 1:340.5sss
#                    all       5606       6279      0.977      0.872      0.905      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.64G        inf     0.3744     0.8866         12        640: 100% ━━━━━━━━━━━━ 1355/1355 1.9it/s 12:03<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 1.9it/s 1:330.6sss
#                    all       5606       6279      0.979      0.867      0.903      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.63G    0.04117     0.3797     0.8869         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.0it/s 11:23<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.7it/s 1:060.4sss
#                    all       5606       6279      0.981      0.861      0.902      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.64G        inf     0.3763     0.8872         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.7it/s 1:050.4sss
#                    all       5606       6279      0.982      0.857        0.9      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.75G        inf     0.3872     0.8863         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.7it/s 1:060.4sss
#                    all       5606       6279       0.98      0.857      0.896      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.75G        inf       0.41     0.8894         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.6it/s 1:080.4sss
#                    all       5606       6279      0.977      0.863      0.898      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.63G    0.06218     0.4462     0.8928         12        640: 100% ━━━━━━━━━━━━ 1355/1355 3.0it/s 7:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.5it/s 1:110.4sss
#                    all       5606       6279      0.966      0.872      0.902      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.68G    0.06826     0.4733     0.8946         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:41<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.6it/s 1:070.4sss
#                    all       5606       6279      0.924      0.858      0.886      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.64G    0.06924      0.481     0.8959         12        640: 100% ━━━━━━━━━━━━ 1355/1355 2.9it/s 7:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 2.7it/s 1:040.4sss
#                    all       5606       6279      0.773      0.766      0.806      0.775
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 51, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 71 epochs completed in 10.381 hours.
# Optimizer stripped from D:\malaria-detection\runs\yolov9\train\weights\last.pt, 15.2MB
# Optimizer stripped from D:\malaria-detection\runs\yolov9\train\weights\best.pt, 15.2MB
#
# Validating D:\malaria-detection\runs\yolov9\train\weights\best.pt...
# Ultralytics 8.4.56  Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv9s summary (fused): 197 layers, 7,167,862 parameters, 0 gradients, 26.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.3s0.3ss
#                    all       5606       6279      0.942      0.938      0.964       0.93
#            parasitized       2805       3478      0.944      0.884      0.938      0.869
#             uninfected       2801       2801      0.939      0.992       0.99       0.99
# Speed: 0.2ms preprocess, 4.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to D:\malaria-detection\runs\yolov9\train

# %% [markdown]
# ## Evaluasi pada Test Set

# %%
# load best weights hasil training
best_weights = os.path.join(SAVE_DIR, 'train', 'weights', 'best.pt')

if not os.path.exists(best_weights):
    raise FileNotFoundError('best.pt tidak ditemukan, pastikan training sudah selesai')

model_best = YOLO(best_weights)
print('best weights loaded dari:', best_weights)
# Out:
# best weights loaded dari: d:\malaria-detection\runs\yolov9\train\weights\best.pt

# %%
# evaluasi di test set
metrics = model_best.val(
    data   = YAML_PATH,
    split  = 'test',
    device = DEVICE,
)

print('\nhasil evaluasi YOLOv9 di test set:')
print(f'  mAP@0.5        : {metrics.box.map50:.4f}')
print(f'  mAP@0.5:0.95   : {metrics.box.map:.4f}')
print(f'  Precision      : {metrics.box.p[0]:.4f}')
print(f'  Recall         : {metrics.box.r[0]:.4f}')
# Out:
# Ultralytics 8.4.56  Python-3.12.3 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv9s summary (fused): 197 layers, 7,167,862 parameters, 0 gradients, 26.7 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 496.8129.4 MB/s, size: 52.9 KB)
# val: Scanning D:\malaria-detection\datasets\processed\labels\test.cache... 2803 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2803/2803  0.0s
# val: D:\malaria-detection\datasets\processed\images\test\mpidb_0235.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 176/176 5.8it/s 30.4s0.2ss
#                    all       2803       3057      0.954      0.942      0.962       0.94
#            parasitized       1406       1660      0.958      0.891      0.933      0.889
#             uninfected       1397       1397       0.95      0.994       0.99       0.99
# Speed: 0.8ms preprocess, 7.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to C:\Users\ASUS\runs\detect\val-9
#
# hasil evaluasi YOLOv9 di test set:
#   mAP@0.5        : 0.9617
#   mAP@0.5:0.95   : 0.9396
#   Precision      : 0.9585
#   Recall         : 0.8910

# %%
# ukur fps rata-rata di test set
test_imgs = list(Path(summary['PATHS']['img_test']).glob('*.jpg'))[:100]

times = []
for img_path in test_imgs:
    img = cv2.imread(str(img_path))
    t0  = time.time()
    model_best.predict(img, verbose=False, device=DEVICE)
    times.append(time.time() - t0)

avg_ms  = (sum(times) / len(times)) * 1000
avg_fps = 1 / (sum(times) / len(times))

print(f'rata-rata inferensi : {avg_ms:.2f} ms')
print(f'rata-rata FPS       : {avg_fps:.1f}')
# Out:
# rata-rata inferensi : 17.38 ms
# rata-rata FPS       : 57.5

# %% [markdown]
# ## Simpan Hasil

# %%
total_params = sum(p.numel() for p in model_best.model.parameters())

precision = float(metrics.box.p[0])
recall    = float(metrics.box.r[0])
f1        = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

nb03_results = {
    'model'        : 'YOLOv9',
    'best_weights' : best_weights,
    'map50'        : round(metrics.box.map50, 4),
    'map50_95'     : round(metrics.box.map, 4),
    'precision'    : round(precision, 4),
    'recall'       : round(recall, 4),
    'f1'           : round(f1, 4),
    'fps'          : round(avg_fps, 2),
    'avg_ms'       : round(avg_ms, 2),
    'total_params' : total_params,
}

result_path = os.path.join(PROJECT_ROOT, 'notebook03_results.json')
with open(result_path, 'w') as f:
    json.dump(nb03_results, f, indent=2)

print('hasil disimpan di:', result_path)
print(json.dumps(nb03_results, indent=2))
# Out:
# hasil disimpan di: d:\malaria-detection\notebook03_results.json
# {
#   "model": "YOLOv9",
#   "best_weights": "d:\\malaria-detection\\runs\\yolov9\\train\\weights\\best.pt",
#   "map50": 0.9617,
#   "map50_95": 0.9396,
#   "precision": 0.9585,
#   "recall": 0.891,
#   "f1": 0.9235,
#   "fps": 57.53,
#   "avg_ms": 17.38,
#   "total_params": 7167862
# }

# %%
print('notebook 03 selesai')
print('best weights:', best_weights)
print()
print('lanjut ke notebook 04_training_yolov8n_cbam.ipynb')
# Out:
# notebook 03 selesai
# best weights: d:\malaria-detection\runs\yolov9\train\weights\best.pt
#
# lanjut ke notebook 04_training_yolov8n_cbam.ipynb
